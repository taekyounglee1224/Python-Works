# %%
#Q1.
def is_odd(n):
  if n%2==1:
    return True
  else:
    return False

# %%
is_odd(13)
# Out:
# True

# %%
#Q2.
def avg_numbers(*args):
  result=0
  for i in args:
    result+=i
  return result/len(args)

# %%
avg_numbers(1,2)
# Out:
# 1.5

# %%
avg_numbers(1,2,3,4,5)
# Out:
# 3.0

# %%
#Q3.
input1=int(input("첫 번째 수를 입력하시오"))
input2=int(input("두 번째 수를 입력하시오"))

total=input1+input2
print("두 수 의 합은 %d 입니다"%total)
# Out:
# 첫 번째 수를 입력하시오 3
# 두 번째 수를 입력하시오 6
# 두 수 의 합은 9 입니다

# %%
#Q4.
print("you""need""python")
print("you"+"need"+"python")
print("you","need","python")
print("".join(["you","need","python"]))
#3번째 코딩의 결과물이 다르다
# Out:
# youneedpython
# youneedpython
# you need python
# youneedpython

# %%
#Q5.
f1=open('test.txt', 'w')
f1.write("Life is too short")
f1.close()

f2=open('test.txt','r')
print(f2.read())
f2.close()
# Out:
# Life is too short

# %%
#Q6.
user_input=input("저장할 내용을 입력하시오")
f=open('test.txt','a')
f.write(user_input)
f.write("Life is too short|n you need Python")
f.close()
# Out:
# 저장할 내용을 입력하시오 Life is too short, you need python

# %%
#Q7.
f=open('test.txt','r')
body=f.read()
f.close()

body=body.replace("java","python")
f=open('test.txt', 'w')
f.write(body)
f.close()

# %%
#Class 1.
#fourcalculation.py
"""A class for four arithmetic calculations"""

class FourCalculation:
    """A class for four arithmetic caluclations"""
    
    def __init__(self,first,second):
        self.first=first
        self.second=second
        #if second is zero, raise an exception
        if second==0:
            raise ValueError('The second number must not be 0')
            
    def add(self):
        return self.first+self.second
    
    def mul(self):
        return self.first*self.second
    
    def sub(self):
        return self.first-self.second
    
    def div(self):
        return self.first/self.second

# %%
b=FourCalculation(8,2)
print(b.first,b.second)
print(b.add(),b.mul(), b.sub(),b.div())
# Out:
# 8 2
# 10 16 6 4.0

# %%
#Class 2.
class Person:
    def __init__(self, first, last):
        self.firstname=first
        self.lastname=last
        
    def Name(self):
        return self.firstname+" "+self.lastname
    
class Student(Person):
    def __init__(self, first, last, studentnum):
        Person. __init__(self, first, last) 
        self.studentnumber=studentnum
    
    def Getstudent(self):
        return self.Name()+ "," +self. studentnumber

# %%
x=Person("TaeKyoung", "Lee")
print(x.Name())
y=Student("TaeKyoung", "Lee", "2022104004")
print(y.Getstudent())
# Out:
# TaeKyoung Lee
# TaeKyoung Lee,2022104004

# %%
#Class 3.
class AreaVolume:
  def __init__(self, radius, height):
    self.radius=radius
    self.height=height
  
  def circle(self):
    return 3.14*(self.radius)**2
  
  
  def cyl(self):
    return 3.14* (self.radius)**2*(self.height)

  def cone(self):
    return (1/3)*3.14*(self.radius)**2*(self.height)

# %%
c=AreaVolume(4,5)
print(c.radius,c.height)
print(f'원의 넓이는 {c.circle()}, 원기둥의 부피는 {c.cyl():.2f}, 원뿔의 부피는 {c.cone():.2f}입니다')
# Out:
# 4 5
# 원의 넓이는 50.24, 원기둥의 부피는 251.20, 원뿔의 부피는 83.73입니다

# %%
#Class 4.
class PhoneNum:
  def __init__(self,name,phnum):
    self.name= name
    self.phnum= phnum
  
  def Address(self):
    return self.name+" "+self.phnum

class Identity(PhoneNum):
  def __init__(self,name,phnum,regnum):
    PhoneNum.__init__(self, name, phnum)
    self.regnum=regnum
  
  def Getidentity(self):
    return self.Address()+" "+self.regnum

# %%
d=PhoneNum("TaeKyoungLee", "01072720913")
print(d.Address())
e=Identity("TaeKyoungLee","01072720913", "0112243077310")
print(e.Getidentity())
# Out:
# TaeKyoungLee 01072720913
# TaeKyoungLee 01072720913 0112243077310

# %%
#Class 5.
class Rectangle:
 
    def __init__(self, width, height):
        self.width = width
        self.height = height
 
    def calcArea(self):
        area = self.width * self.height
        return area

# %%
f=Rectangle(10,8)
print(f.calcArea())
# Out:
# 80

# %%
#Class 6
class Name:
  def __init__(self, korean_name, english_name):
    self.korean_name=korean_name
    self.english_name=english_name

  def myname(self):
    return self.korean_name+"     "+self.english_name
  
g=Name("TaeKyoung Lee","Ted Lee")
print(g.myname())
# Out:
# TaeKyoung Lee     Ted Lee

# %%
#사물 예시 class
class Smartphone:
    smartphone_count = 0
    
    def __init__(self, brand, info):
        self.brand = brand
        self.info = info
        Smartphone.smartphone_count += 1

    def __str__(self):
        return f'str : {self.brand} - {self.info}'

    def __repr__(self):
        return f'repr : {self.brand} - {self.info}'

    def infomation(self):
        print(f'Current Id : {id(self)}')
        print(f'Smartphone Detail Info : {self.brand} {self.infomations.get}')

    def __del__(self):
        Smartphone.smartphone_count -= 1
    
Smartphone1 = Smartphone('Iphone', {'color' : 'White', 'price': 10000})
Smartphone2 = Smartphone('Galaxy', {'color' : 'Black', 'price': 8000})
	

print(Smartphone1.__dict__)
print(Smartphone2.__dict__)
print(Smartphone1.__str__())
print(Smartphone2.__repr__())
	
print(Smartphone1.smartphone_count)
print(Smartphone.smartphone_count)
# Out:
# {'brand': 'Iphone', 'info': {'color': 'White', 'price': 10000}}
# {'brand': 'Galaxy', 'info': {'color': 'Black', 'price': 8000}}
# str : Iphone - {'color': 'White', 'price': 10000}
# repr : Galaxy - {'color': 'Black', 'price': 8000}
# 2
# 2

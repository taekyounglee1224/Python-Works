# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('apt.csv',encoding='cp949')

# %%
df
# Out:
#                  지역      번지   본번  부번           아파트       면적    계약년월  계약일  \
# 0       강원도 강릉시 견소동     202  202   0          송정한신   59.800  201910    4
# 1       강원도 강릉시 견소동     202  202   0          송정한신  116.175  201910   31
# 2       강원도 강릉시 견소동     289  289   0  송정해변신도브래뉴아파트   84.990  201910    5
# 3       강원도 강릉시 견소동     289  289   0  송정해변신도브래뉴아파트   84.990  201910   12
# 4       강원도 강릉시 견소동     289  289   0  송정해변신도브래뉴아파트   84.990  201910   20
# ...             ...     ...  ...  ..           ...      ...     ...  ...
# 42753  충청북도 충주시 호암동   547-6  547   6          호반현대   59.760  201910   29
# 42754  충청북도 충주시 호암동  221-23  221  23    호암리버빌(1단지)   84.680  201910    5
# 42755  충청북도 충주시 호암동  221-23  221  23    호암리버빌(1단지)   84.680  201910   15
# 42756  충청북도 충주시 호암동  221-23  221  23    호암리버빌(1단지)   84.680  201910   17
# 42757  충청북도 충주시 호암동  221-23  221  23    호암리버빌(1단지)   84.680  201910   26
#
#           가격   층  건축년도           도로명
# 0      10900   5  1997   경강로2539번길 8
# ...

# %%
#분석1. 건축년도에 따른 건물의 층수
plt.scatter(df['건축년도'],df['층'])
plt.xlabel('Built Year',fontsize=10)
plt.ylabel('Floors',fontsize=10)
plt.show()
#분석 결과: 최근에 지어진 건물일수록 고층 건물이 많다.

# %%
df1=df.loc[:, ['지역','건축년도','층','면적','가격']] [df.지역=='서울특별시 서초구 서초동'] [df.건축년도>1995] [df.층<25]
df1
# Out:
# <ipython-input-43-93af15ab501a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1=df.loc[:, ['지역','건축년도','층','면적','가격']] [df.지역=='서울특별시 서초구 서초동'] [df.건축년도>1995] [df.층<25]
#                   지역  건축년도   층        면적      가격
# 29978  서울특별시 서초구 서초동  2014   8   20.3340   23500
# 29979  서울특별시 서초구 서초동  2014   5   20.4060   22500
# 29980  서울특별시 서초구 서초동  2014   8   18.5300   32300
# 29981  서울특별시 서초구 서초동  2006   5   59.9700   78000
# 29982  서울특별시 서초구 서초동  2004  10   84.9910  137000
# 29983  서울특별시 서초구 서초동  2002   7   84.9000  120000
# 29984  서울특별시 서초구 서초동  2006  13  100.4500  125500
# 29985  서울특별시 서초구 서초동  2009  22   59.9958  163000
# 29986  서울특별시 서초구 서초동  2016  22   83.6000  210000
# 29987  서울특별시 서초구 서초동  2006  13   84.9800  176000
# 29990  서울특별시 서초구 서초동  2010   6   59.9000  147500
# 29991  서울특별시 서초구 서초동  2004  11  130.5300  164500
# 29992  서울특별시 서초구 서초동  2005   2   84.9900  120000
# 29993  서울특별시 서초구 서초동  2005   2  125.7900  150000
# ...

# %%
#분석2: 서울시 서초구 서초동에 1995년도 이후 지어진 아파트 중 25층 이하 아파트의 총 면적에 따른 매매가격 추이 
df1.figsize=(10,10)
plt.scatter(df1['면적']*df1['층'],df1['가격'])
plt.xlabel('Total Area',fontsize=10)
plt.ylabel('Price',fontsize=10)
plt.show()
#분석결과: 총 면적(면적*층수)가 클 수록 가격이 올라간다.

# %%
df['단가']=df.가격/df.면적
df2=df.loc[5720:6653, ['지역','가격','면적','단가','건축년도']] [df.건축년도>2000]
df2
# Out:
# <ipython-input-46-d2f31fb51442>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2=df.loc[5720:6653, ['지역','가격','면적','단가','건축년도']] [df.건축년도>2000]
#                  지역     가격        면적          단가  건축년도
# 5720  경기도 수원영통구 망포동  59000  129.4884  455.639270  2010
# 5721  경기도 수원영통구 망포동  50800  115.7772  438.773783  2010
# 5722  경기도 수원영통구 망포동  58100  129.4884  448.688840  2010
# 5723  경기도 수원영통구 망포동  54000  115.7772  466.413076  2010
# 5724  경기도 수원영통구 망포동  54800  129.4884  423.203932  2010
# ...             ...    ...       ...         ...   ...
# 6649   경기도 수원영통구 하동  61500   84.7654  725.531880  2012
# 6650   경기도 수원영통구 하동  78000   84.9600  918.079096  2011
# 6651   경기도 수원영통구 하동  73300   84.8500  863.877431  2011
# 6652   경기도 수원영통구 하동  95000  111.6500  850.873265  2011
# 6653   경기도 수원영통구 하동  90000  111.0800  810.226864  2011
#
# [558 rows x 5 columns]

# %%
#분석3: 경기도 수원영통구에 지어진 아파트 중 2000년도 이후에 지어진 아파트들의 건축년도에 따른 단가 추이
plt.scatter(df2['건축년도'],df2['단가'])
plt.xlabel('Built year',fontsize=10)
plt.ylabel('Unit Price',fontsize=10)
plt.show()
#분석 결과: 최근에 지어진 아파트일수록 전체적으로 단가가 높아지는 추세
            #대략 2007년도를 기점으로 급격하게 단가가 증가하였고, 2011~2014년 사이에 단가가 가장 높았다.
